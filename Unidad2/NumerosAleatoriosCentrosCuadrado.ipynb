# %% [markdown]
# # Simulación
# ## Unidad 2
# ### Práctica 1. Generación de números aleatorios por el método de centros al cuadrado
#
# Docente: José Gabriel Rodríguez Rivas
#
# Alumno: Emanuel Magallanes Contreras

# %%
# Semilla inicial
semilla = 2005 
n = 4
iteraciones = 100
resultados = []

for _ in range (iteraciones):
    # Elevar la semilla al cuadrado
    cuadrado = str(semilla ** 2).zfill(2*n) # Agregar los espacios necesarios
    # Extraer los digitos centrales 
    inicio = (len(cuadrado)-n) // 2
    semilla = int (cuadrado[inicio:inicio + n])
    resultados.append(semilla)

# Imprimir los resultados
for i, numero in enumerate(resultados, 1):
    print(f"Numero aleatorio (i): {numero}")
# Out:
# Numero aleatorio (i): 200
# Numero aleatorio (i): 400
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
# Numero aleatorio (i): 3600
# Numero aleatorio (i): 9600
# Numero aleatorio (i): 1600
# Numero aleatorio (i): 5600
